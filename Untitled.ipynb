# %%
# %load_ext nb_black
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import pprint
from config import app_key
import pymongo
from time import time, sleep

url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"
parameters = {"start": 1, "limit": 1000, "convert": "USD"}
headers = {
    "Accept": "application/json",
    "X-CMC_PRO_API_KEY": app_key,
}
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
session = Session()
session.headers.update(headers)
data_retrieved = []
pp = pprint.PrettyPrinter(width=10, compact=True)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    pp.pprint(data)
    data_retrieved.append(data)

except (ConnectionError, Timeout, TooManyRedirects) as error:
    data_retrieved(error)
# Out:
# {'data': [{'circulating_supply': 19020068,
#            'cmc_rank': 1,
#            'date_added': '2013-04-28T00:00:00.000Z',
#            'id': 1,
#            'last_updated': '2022-04-23T19:42:00.000Z',
#            'max_supply': 21000000,
#            'name': 'Bitcoin',
#            'num_market_pairs': 9357,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 834381083940.11,
#                              'last_updated': '2022-04-23T19:42:00.000Z',
#                              'market_cap': 755713569259.7465,
#                              'market_cap_dominance': 40.8958,
#                              'percent_change_1h': -0.03454007,
#                              'percent_change_24h': 0.00392774,
#                              'percent_change_30d': -9.73304296,
#                              'percent_change_60d': 4.5347971,
#                              'percent_change_7d': -1.24834054,
#                              'percent_change_90d': 13.78184666,
#                              'price': 39732.432568576856,
#                              'volume_24h': 16659297331.012177,
#                              'volume_change_24h': -47.3935}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'bitcoin',
#            'symbol': 'BTC',
#            'tags': ['mineable',
#                     'pow',
#                     'sha-256',
#                     'store-of-value',
#                     'state-channel',
#                     'coinbase-ventures-portfolio',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'binance-labs-portfolio',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'cms-holdings-portfolio',
#                     'dcg-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'electric-capital-portfolio',
#                     'fabric-ventures-portfolio',
#                     'framework-ventures-portfolio',
#                     'galaxy-digital-portfolio',
#                     'huobi-capital-portfolio',
#                     'alameda-research-portfolio',
#                     'a16z-portfolio',
#                     '1confirmation-portfolio',
#                     'winklevoss-capital-portfolio',
#                     'usv-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'multicoin-capital-portfolio',
#                     'paradigm-portfolio'],
#            'total_supply': 19020068},
#           {'circulating_supply': 120498628.0615,
#            'cmc_rank': 2,
#            'date_added': '2015-08-07T00:00:00.000Z',
#            'id': 1027,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Ethereum',
#            'num_market_pairs': 5661,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 355651397555.98,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 355651397555.9765,
#                              'market_cap_dominance': 19.2455,
#                              'percent_change_1h': -0.0570114,
#                              'percent_change_24h': -0.88732177,
#                              'percent_change_30d': -5.25814418,
#                              'percent_change_60d': 12.74858299,
#                              'percent_change_7d': -2.50727359,
#                              'percent_change_90d': 22.70137582,
#                              'price': 2951.497484058154,
#                              'volume_24h': 9715132252.036562,
#                              'volume_change_24h': -49.767}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'ethereum',
#            'symbol': 'ETH',
#            'tags': ['mineable',
#                     'pow',
#                     'smart-contracts',
#                     'ethereum-ecosystem',
#                     'coinbase-ventures-portfolio',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'binance-labs-portfolio',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'cms-holdings-portfolio',
#                     'dcg-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'electric-capital-portfolio',
#                     'fabric-ventures-portfolio',
#                     'framework-ventures-portfolio',
#                     'hashkey-capital-portfolio',
#                     'kenetic-capital-portfolio',
#                     'huobi-capital-portfolio',
#                     'alameda-research-portfolio',
#                     'a16z-portfolio',
#                     '1confirmation-portfolio',
#                     'winklevoss-capital-portfolio',
#                     'usv-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'multicoin-capital-portfolio',
#                     'paradigm-portfolio',
#                     'injective-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 120498628.0615},
#           {'circulating_supply': 83114200517.6541,
#            'cmc_rank': 3,
#            'date_added': '2015-02-25T00:00:00.000Z',
#            'id': 825,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Tether',
#            'num_market_pairs': 32249,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#            'quote': {'USD': {'fully_diluted_market_cap': 85738803406.61,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 83138298346.30513,
#                              'market_cap_dominance': 4.5004,
#                              'percent_change_1h': 0.00296519,
#                              'percent_change_24h': 0.0048183,
#                              'percent_change_30d': -0.0211812,
#                              'percent_change_60d': -0.04337347,
#                              'percent_change_7d': 0.00228356,
#                              'percent_change_90d': -0.01651692,
#                              'price': 1.0002899363586601,
#                              'volume_24h': 39156264473.53239,
#                              'volume_change_24h': -42.8291}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'tether',
#            'symbol': 'USDT',
#            'tags': ['payments',
#                     'stablecoin',
#                     'asset-backed-stablecoin',
#                     'avalanche-ecosystem',
#                     'solana-ecosystem',
#                     'arbitrum-ecosytem',
#                     'moonriver-ecosystem',
#                     'injective-ecosystem',
#                     'bnb-chain',
#                     'usd-stablecoin'],
#            'total_supply': 85713951815.53561},
#           {'circulating_supply': 163276974.63,
#            'cmc_rank': 4,
#            'date_added': '2017-07-25T00:00:00.000Z',
#            'id': 1839,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 165116760,
#            'name': 'BNB',
#            'num_market_pairs': 813,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 67078128747.07,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 66330722124.530945,
#                              'market_cap_dominance': 3.5902,
#                              'percent_change_1h': 0.01612608,
#                              'percent_change_24h': -0.77638877,
#                              'percent_change_30d': -2.12009876,
#                              'percent_change_60d': 9.49942294,
#                              'percent_change_7d': -1.93115804,
#                              'percent_change_90d': 10.93434279,
#                              'price': 406.2466387244264,
#                              'volume_24h': 1408557841.8988905,
#                              'volume_change_24h': -32.9455}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'bnb',
#            'symbol': 'BNB',
#            'tags': ['marketplace',
#                     'centralized-exchange',
#                     'payments',
#                     'smart-contracts',
#                     'alameda-research-portfolio',
#                     'multicoin-capital-portfolio',
#                     'moonriver-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 163276974.63},
#           {'circulating_supply': 49892351394.13943,
#            'cmc_rank': 5,
#            'date_added': '2018-10-08T00:00:00.000Z',
#            'id': 3408,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'USD '
#                    'Coin',
#            'num_market_pairs': 3801,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#            'quote': {'USD': {'fully_diluted_market_cap': 49910868060.63,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 49910868060.63381,
#                              'market_cap_dominance': 2.7006,
#                              'percent_change_1h': 0.04559234,
#                              'percent_change_24h': -0.00666118,
#                              'percent_change_30d': 0.06656017,
#                              'percent_change_60d': -0.0036199,
#                              'percent_change_7d': 0.04515749,
#                              'percent_change_90d': 0.10015213,
#                              'price': 1.0003711323675268,
#                              'volume_24h': 2451965219.441212,
#                              'volume_change_24h': -42.826}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'usd-coin',
#            'symbol': 'USDC',
#            'tags': ['medium-of-exchange',
#                     'stablecoin',
#                     'asset-backed-stablecoin',
#                     'fantom-ecosystem',
#                     'arbitrum-ecosytem',
#                     'moonriver-ecosystem',
#                     'bnb-chain',
#                     'usd-stablecoin'],
#            'total_supply': 49892351394.13943},
#           {'circulating_supply': 48105234849,
#            'cmc_rank': 6,
#            'date_added': '2013-08-04T00:00:00.000Z',
#            'id': 52,
#            'last_updated': '2022-04-23T19:42:00.000Z',
#            'max_supply': 100000000000,
#            'name': 'XRP',
#            'num_market_pairs': 712,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 71173413201.99,
#                              'last_updated': '2022-04-23T19:42:00.000Z',
#                              'market_cap': 34238137570.868317,
#                              'market_cap_dominance': 1.8527,
#                              'percent_change_1h': -0.04975141,
#                              'percent_change_24h': -2.59877679,
#                              'percent_change_30d': -16.06055435,
#                              'percent_change_60d': 1.16922054,
#                              'percent_change_7d': -8.04189227,
#                              'percent_change_90d': 19.17009288,
#                              'price': 0.7117341320199386,
#                              'volume_24h': 1384607270.497342,
#                              'volume_change_24h': -32.7566}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'xrp',
#            'symbol': 'XRP',
#            'tags': ['medium-of-exchange',
#                     'enterprise-solutions',
#                     'binance-chain',
#                     'arrington-xrp-capital-portfolio',
#                     'galaxy-digital-portfolio',
#                     'a16z-portfolio',
#                     'pantera-capital-portfolio'],
#            'total_supply': 99989594553},
#           {'circulating_supply': 333568648.17130154,
#            'cmc_rank': 7,
#            'date_added': '2020-04-10T00:00:00.000Z',
#            'id': 5426,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Solana',
#            'num_market_pairs': 295,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 52081215662.3,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 33956382474.39702,
#                              'market_cap_dominance': 1.8379,
#                              'percent_change_1h': -0.40194889,
#                              'percent_change_24h': 0.04283036,
#                              'percent_change_30d': -1.57093362,
#                              'percent_change_60d': 18.84784557,
#                              'percent_change_7d': -0.76360586,
#                              'percent_change_90d': 7.09050697,
#                              'price': 101.79728418888752,
#                              'volume_24h': 849262803.6040981,
#                              'volume_change_24h': -45.4973}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'solana',
#            'symbol': 'SOL',
#            'tags': ['pos',
#                     'platform',
#                     'solana-ecosystem',
#                     'cms-holdings-portfolio',
#                     'kenetic-capital-portfolio',
#                     'alameda-research-portfolio',
#                     'multicoin-capital-portfolio',
#                     'okex-blockdream-ventures-portfolio'],
#            'total_supply': 511616946.142289},
#           {'circulating_supply': 349605168.6971733,
#            'cmc_rank': 8,
#            'date_added': '2019-07-26T00:00:00.000Z',
#            'id': 4172,
#            'last_updated': '2022-04-23T19:42:00.000Z',
#            'max_supply': None,
#            'name': 'Terra',
#            'num_market_pairs': 226,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 66894434107.37,
#                              'last_updated': '2022-04-23T19:42:00.000Z',
#                              'market_cap': 31908213998.349556,
#                              'market_cap_dominance': 1.7267,
#                              'percent_change_1h': -0.3966981,
#                              'percent_change_24h': -3.81331286,
#                              'percent_change_30d': -2.65290879,
#                              'percent_change_60d': 68.74816865,
#                              'percent_change_7d': 13.28424694,
#                              'percent_change_90d': 40.250461,
#                              'price': 91.26928562657588,
#                              'volume_24h': 1279494570.823605,
#                              'volume_change_24h': -56.0056}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'terra-luna',
#            'symbol': 'LUNA',
#            'tags': ['cosmos-ecosystem',
#                     'store-of-value',
#                     'defi',
#                     'payments',
#                     'coinbase-ventures-portfolio',
#                     'binance-labs-portfolio',
#                     'solana-ecosystem',
#                     'arrington-xrp-capital-portfolio',
#                     'hashkey-capital-portfolio',
#                     'kenetic-capital-portfolio',
#                     'huobi-capital-portfolio',
#                     'pantera-capital-portfolio',
#                     'terra-ecosystem'],
#            'total_supply': 732934783.570743},
#           {'circulating_supply': 33752555544.074,
#            'cmc_rank': 9,
#            'date_added': '2017-10-01T00:00:00.000Z',
#            'id': 2010,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 45000000000,
#            'name': 'Cardano',
#            'num_market_pairs': 426,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 40418811874.88,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 30316404285.161858,
#                              'market_cap_dominance': 1.6409,
#                              'percent_change_1h': -0.16476892,
#                              'percent_change_24h': -1.09142873,
#                              'percent_change_30d': -23.64266311,
#                              'percent_change_60d': 1.32377752,
#                              'percent_change_7d': -4.76917478,
#                              'percent_change_90d': -15.65945234,
#                              'price': 0.8981958194417242,
#                              'volume_24h': 457131496.8769009,
#                              'volume_change_24h': -46.4017}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'cardano',
#            'symbol': 'ADA',
#            'tags': ['mineable',
#                     'dpos',
#                     'pos',
#                     'platform',
#                     'research',
#                     'smart-contracts',
#                     'staking',
#                     'cardano-ecosystem',
#                     'cardano',
#                     'bnb-chain'],
#            'total_supply': 34277702081.605},
#           {'circulating_supply': 268619838.79032975,
#            'cmc_rank': 10,
#            'date_added': '2020-07-13T00:00:00.000Z',
#            'id': 5805,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Avalanche',
#            'num_market_pairs': 234,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 29154303478.41,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 19781754486.510406,
#                              'market_cap_dominance': 1.0705,
#                              'percent_change_1h': -0.1685725,
#                              'percent_change_24h': -1.52397172,
#                              'percent_change_30d': -15.35022332,
#                              'percent_change_60d': 1.33672619,
#                              'percent_change_7d': -5.01165498,
#                              'percent_change_90d': 20.4180405,
#                              'price': 73.6421947671221,
#                              'volume_24h': 347928273.83174723,
#                              'volume_change_24h': -44.1471}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'avalanche',
#            'symbol': 'AVAX',
#            'tags': ['defi',
#                     'smart-contracts',
#                     'polychain-capital-portfolio',
#                     'avalanche-ecosystem',
#                     'cms-holdings-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'moonriver-ecosystem',
#                     'injective-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 395891289.9134107},
#           {'circulating_supply': 987579314.957085,
#            'cmc_rank': 11,
#            'date_added': '2020-08-19T00:00:00.000Z',
#            'id': 6636,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Polkadot',
#            'num_market_pairs': 332,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 20884196724.23,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 18693678783.144188,
#                              'market_cap_dominance': 1.0119,
#                              'percent_change_1h': -0.52711879,
#                              'percent_change_24h': 3.05511632,
#                              'percent_change_30d': -10.83255547,
#                              'percent_change_60d': 16.02921374,
#                              'percent_change_7d': 2.66274103,
#                              'percent_change_90d': 5.75551775,
#                              'price': 18.92878728829645,
#                              'volume_24h': 625675470.5988094,
#                              'volume_change_24h': -12.8501}},
#            'self_reported_circulating_supply': 904869778,
#            'self_reported_market_cap': 17128087551.370031,
#            'slug': 'polkadot-new',
#            'symbol': 'DOT',
#            'tags': ['substrate',
#                     'polkadot',
#                     'binance-chain',
#                     'polkadot-ecosystem',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'arrington-xrp-capital-portfolio',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'cms-holdings-portfolio',
#                     'coinfund-portfolio',
#                     'fabric-ventures-portfolio',
#                     'fenbushi-capital-portfolio',
#                     'hashkey-capital-portfolio',
#                     'kenetic-capital-portfolio',
#                     '1confirmation-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'exnetwork-capital-portfolio',
#                     'web3',
#                     'spartan-group',
#                     'injective-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 1103303471.382273},
#           {'circulating_supply': 18077364571.160988,
#            'cmc_rank': 12,
#            'date_added': '2020-09-21T00:00:00.000Z',
#            'id': 7129,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'TerraUSD',
#            'num_market_pairs': 515,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 18077840575.36,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 18077840575.362686,
#                              'market_cap_dominance': 0.9785,
#                              'percent_change_1h': -0.12502354,
#                              'percent_change_24h': -0.25123281,
#                              'percent_change_30d': -0.03784977,
#                              'percent_change_60d': -0.204108,
#                              'percent_change_7d': -0.14965158,
#                              'percent_change_90d': 0.21831189,
#                              'price': 1.0000263315042315,
#                              'volume_24h': 359580993.05150574,
#                              'volume_change_24h': -42.5337}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'terrausd',
#            'symbol': 'UST',
#            'tags': ['cosmos-ecosystem',
#                     'stablecoin',
#                     'terra-ecosystem',
#                     'injective-ecosystem',
#                     'bnb-chain',
#                     'usd-stablecoin'],
#            'total_supply': 18077364571.160988},
#           {'circulating_supply': 132670764299.89409,
#            'cmc_rank': 13,
#            'date_added': '2013-12-15T00:00:00.000Z',
#            'id': 74,
#            'last_updated': '2022-04-23T19:42:00.000Z',
#            'max_supply': None,
#            'name': 'Dogecoin',
#            'num_market_pairs': 466,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 17943395577.09,
#                              'last_updated': '2022-04-23T19:42:00.000Z',
#                              'market_cap': 17943395577.086517,
#                              'market_cap_dominance': 0.971,
#                              'percent_change_1h': 0.08453337,
#                              'percent_change_24h': -0.92507966,
#                              'percent_change_30d': -1.62901729,
#                              'percent_change_60d': 3.89204561,
#                              'percent_change_7d': -5.07621068,
#                              'percent_change_90d': -1.00862631,
#                              'price': 0.13524754810733267,
#                              'volume_24h': 344756189.48911136,
#                              'volume_change_24h': -43.2673}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'dogecoin',
#            'symbol': 'DOGE',
#            'tags': ['mineable',
#                     'pow',
#                     'scrypt',
#                     'medium-of-exchange',
#                     'memes',
#                     'payments',
#                     'doggone-doggerel',
#                     'bnb-chain'],
#            'total_supply': 132670764299.89409},
#           {'circulating_supply': 17558654053.969254,
#            'cmc_rank': 14,
#            'date_added': '2019-09-20T00:00:00.000Z',
#            'id': 4687,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Binance '
#                    'USD',
#            'num_market_pairs': 3552,
#            'platform': {'id': 1839,
#                         'name': 'BNB '
#                                 'Beacon '
#                                 'Chain '
#                                 '(BEP2)',
#                         'slug': 'bnb',
#                         'symbol': 'BNB',
#                         'token_address': 'BUSD-BD1'},
#            'quote': {'USD': {'fully_diluted_market_cap': 17539307513.59,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 17539307513.590195,
#                              'market_cap_dominance': 0.949,
#                              'percent_change_1h': -0.18029975,
#                              'percent_change_24h': -0.19253473,
#                              'percent_change_30d': -0.23206814,
#                              'percent_change_60d': -0.21425589,
#                              'percent_change_7d': -0.07542581,
#                              'percent_change_90d': -0.15347417,
#                              'price': 0.9988981763454309,
#                              'volume_24h': 2649607180.485738,
#                              'volume_change_24h': -44.3169}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'binance-usd',
#            'symbol': 'BUSD',
#            'tags': ['stablecoin',
#                     'asset-backed-stablecoin',
#                     'binance-chain',
#                     'harmony-ecosystem',
#                     'moonriver-ecosystem',
#                     'bnb-chain',
#                     'usd-stablecoin'],
#            'total_supply': 17558654053.969254},
#           {'circulating_supply': 549063278876301.94,
#            'cmc_rank': 15,
#            'date_added': '2020-08-01T00:00:00.000Z',
#            'id': 5994,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Shiba '
#                    'Inu',
#            'num_market_pairs': 337,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#            'quote': {'USD': {'fully_diluted_market_cap': 14276069264.84,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 13291503803.994225,
#                              'market_cap_dominance': 0.7192,
#                              'percent_change_1h': -0.14170541,
#                              'percent_change_24h': -0.47990543,
#                              'percent_change_30d': -2.4222629,
#                              'percent_change_60d': -1.80966798,
#                              'percent_change_7d': -5.20319977,
#                              'percent_change_90d': 13.14385664,
#                              'price': 2.420759922462172e-05,
#                              'volume_24h': 315872649.27564925,
#                              'volume_change_24h': -36.7626}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'shiba-inu',
#            'symbol': 'SHIB',
#            'tags': ['memes',
#                     'ethereum-ecosystem',
#                     'doggone-doggerel'],
#            'total_supply': 589735030408322.8},
#           {'circulating_supply': 280605.33068486,
#            'cmc_rank': 16,
#            'date_added': '2019-01-30T00:00:00.000Z',
#            'id': 3717,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Wrapped '
#                    'Bitcoin',
#            'num_market_pairs': 409,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#            'quote': {'USD': {'fully_diluted_market_cap': 11145186912.63,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 11145186912.628056,
#                              'market_cap_dominance': 0.6031,
#                              'percent_change_1h': -0.02902115,
#                              'percent_change_24h': 0.03419124,
#                              'percent_change_30d': -9.74672473,
#                              'percent_change_60d': 5.01623572,
#                              'percent_change_7d': -1.22622871,
#                              'percent_change_90d': 13.30123921,
#                              'price': 39718.37201177373,
#                              'volume_24h': 108789921.32547408,
#                              'volume_change_24h': -52.177}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'wrapped-bitcoin',
#            'symbol': 'WBTC',
#            'tags': ['medium-of-exchange',
#                     'defi',
#                     'wrapped-tokens',
#                     'fantom-ecosystem',
#                     'arbitrum-ecosytem',
#                     'moonriver-ecosystem'],
#            'total_supply': 280605.33068486},
#           {'circulating_supply': 7814866566.62,
#            'cmc_rank': 17,
#            'date_added': '2019-04-28T00:00:00.000Z',
#            'id': 3890,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 10000000000,
#            'name': 'Polygon',
#            'num_market_pairs': 372,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 13772031288.95,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 10762658687.445948,
#                              'market_cap_dominance': 0.5824,
#                              'percent_change_1h': -0.53553247,
#                              'percent_change_24h': -3.13941807,
#                              'percent_change_30d': -15.18273524,
#                              'percent_change_60d': -4.02077781,
#                              'percent_change_7d': -0.10984389,
#                              'percent_change_90d': -10.43849743,
#                              'price': 1.3772031288949946,
#                              'volume_24h': 576033164.7555605,
#                              'volume_change_24h': -57.156}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'polygon',
#            'symbol': 'MATIC',
#            'tags': ['platform',
#                     'enterprise-solutions',
#                     'scaling',
#                     'state-channel',
#                     'coinbase-ventures-portfolio',
#                     'binance-launchpad',
#                     'binance-labs-portfolio',
#                     'polygon-ecosystem',
#                     'moonriver-ecosystem',
#                     'injective-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 10000000000},
#           {'circulating_supply': 678122788,
#            'cmc_rank': 18,
#            'date_added': '2020-08-11T00:00:00.000Z',
#            'id': 6535,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 1000000000,
#            'name': 'NEAR '
#                    'Protocol',
#            'num_market_pairs': 130,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 15530009379.66,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 10531253258.201113,
#                              'market_cap_dominance': 0.57,
#                              'percent_change_1h': 0.1377567,
#                              'percent_change_24h': 0.13421942,
#                              'percent_change_30d': 22.0065102,
#                              'percent_change_60d': 77.0416317,
#                              'percent_change_7d': -0.75049039,
#                              'percent_change_90d': 39.8673424,
#                              'price': 15.530009379659885,
#                              'volume_24h': 611453972.3873113,
#                              'volume_change_24h': -42.8027}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'near-protocol',
#            'symbol': 'NEAR',
#            'tags': ['platform',
#                     'staking',
#                     'coinbase-ventures-portfolio',
#                     'arrington-xrp-capital-portfolio',
#                     'coinfund-portfolio',
#                     'electric-capital-portfolio',
#                     'fabric-ventures-portfolio',
#                     'kenetic-capital-portfolio',
#                     'near-protocol-ecosystem',
#                     'injective-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 1000000000},
#           {'circulating_supply': 25263013692,
#            'cmc_rank': 19,
#            'date_added': '2018-12-14T00:00:00.000Z',
#            'id': 3635,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 30263013692,
#            'name': 'Cronos',
#            'num_market_pairs': 132,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#            'quote': {'USD': {'fully_diluted_market_cap': 12322713113.55,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 10286776897.980574,
#                              'market_cap_dominance': 0.5567,
#                              'percent_change_1h': -0.04468329,
#                              'percent_change_24h': 1.26479806,
#                              'percent_change_30d': -8.90749149,
#                              'percent_change_60d': 2.36247937,
#                              'percent_change_7d': -0.01297443,
#                              'percent_change_90d': 12.61561109,
#                              'price': 0.4071872431133611,
#                              'volume_24h': 40102986.96818667,
#                              'volume_change_24h': -19.1889}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'cronos',
#            'symbol': 'CRO',
#            'tags': ['medium-of-exchange',
#                     'cosmos-ecosystem',
#                     'centralized-exchange',
#                     'mobile',
#                     'payments'],
#            'total_supply': 30263013692},
#           {'circulating_supply': 9076239154.172836,
#            'cmc_rank': 20,
#            'date_added': '2019-11-22T00:00:00.000Z',
#            'id': 4943,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Dai',
#            'num_market_pairs': 919,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#            'quote': {'USD': {'fully_diluted_market_cap': 9071103164.69,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 9071103164.69405,
#                              'market_cap_dominance': 0.4908,
#                              'percent_change_1h': 0.00937969,
#                              'percent_change_24h': -0.03580184,
#                              'percent_change_30d': -0.03705488,
#                              'percent_change_60d': -0.0827427,
#                              'percent_change_7d': -0.04355881,
#                              'percent_change_90d': 0.02602662,
#                              'price': 0.9994341280136471,
#                              'volume_24h': 243101172.0211984,
#                              'volume_change_24h': -33.234}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'multi-collateral-dai',
#            'symbol': 'DAI',
#            'tags': ['defi',
#                     'stablecoin',
#                     'ethereum-ecosystem',
#                     'avalanche-ecosystem',
#                     'polygon-ecosystem',
#                     'fantom-ecosystem',
#                     'arbitrum-ecosytem',
#                     'harmony-ecosystem',
#                     'moonriver-ecosystem',
#                     'bnb-chain',
#                     'usd-stablecoin'],
#            'total_supply': 9076239154.172836},
#           {'circulating_supply': 70133281.27791464,
#            'cmc_rank': 21,
#            'date_added': '2013-04-28T00:00:00.000Z',
#            'id': 2,
#            'last_updated': '2022-04-23T19:42:00.000Z',
#            'max_supply': 84000000,
#            'name': 'Litecoin',
#            'num_market_pairs': 765,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 8914750152.36,
#                              'last_updated': '2022-04-23T19:42:00.000Z',
#                              'market_cap': 7443103332.830803,
#                              'market_cap_dominance': 0.4028,
#                              'percent_change_1h': -0.11268149,
#                              'percent_change_24h': -1.07355689,
#                              'percent_change_30d': -15.29038435,
#                              'percent_change_60d': -0.40212638,
#                              'percent_change_7d': -4.4963688,
#                              'percent_change_90d': -1.24116505,
#                              'price': 106.12797800428422,
#                              'volume_24h': 547358305.228124,
#                              'volume_change_24h': -22.7507}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'litecoin',
#            'symbol': 'LTC',
#            'tags': ['mineable',
#                     'pow',
#                     'scrypt',
#                     'medium-of-exchange',
#                     'binance-chain',
#                     'bnb-chain'],
#            'total_supply': 84000000},
#           {'circulating_supply': 101632701818.03636,
#            'cmc_rank': 22,
#            'date_added': '2017-09-13T00:00:00.000Z',
#            'id': 1958,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'TRON',
#            'num_market_pairs': 593,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 6861228815.85,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 6861228265.835776,
#                              'market_cap_dominance': 0.3714,
#                              'percent_change_1h': -0.12045148,
#                              'percent_change_24h': -0.74629823,
#                              'percent_change_30d': 3.02605244,
#                              'percent_change_60d': 8.55674962,
#                              'percent_change_7d': 10.12492954,
#                              'percent_change_90d': 20.69010068,
#                              'price': 0.0675100449274698,
#                              'volume_24h': 858041526.6436023,
#                              'volume_change_24h': -63.5867}},
#            'self_reported_circulating_supply': 71659659264,
#            'self_reported_market_cap': 4837746816.399817,
#            'slug': 'tron',
#            'symbol': 'TRX',
#            'tags': ['media',
#                     'payments',
#                     'tron-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 101632709965.20477},
#           {'circulating_supply': 286370297,
#            'cmc_rank': 23,
#            'date_added': '2019-03-14T00:00:00.000Z',
#            'id': 3794,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Cosmos',
#            'num_market_pairs': 273,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 0,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 6632114769.350806,
#                              'market_cap_dominance': 0.3589,
#                              'percent_change_1h': -0.06245917,
#                              'percent_change_24h': -0.44343904,
#                              'percent_change_30d': -20.91303459,
#                              'percent_change_60d': -5.20180883,
#                              'percent_change_7d': -3.69723444,
#                              'percent_change_90d': -27.40843066,
#                              'price': 23.159227192304815,
#                              'volume_24h': 284608760.00409067,
#                              'volume_change_24h': -35.9923}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'cosmos',
#            'symbol': 'ATOM',
#            'tags': ['platform',
#                     'cosmos-ecosystem',
#                     'content-creation',
#                     'interoperability',
#                     'binance-chain',
#                     'polychain-capital-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'hashkey-capital-portfolio',
#                     '1confirmation-portfolio',
#                     'paradigm-portfolio',
#                     'exnetwork-capital-portfolio',
#                     'injective-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 0},
#           {'circulating_supply': 467009549.5205637,
#            'cmc_rank': 24,
#            'date_added': '2017-09-20T00:00:00.000Z',
#            'id': 1975,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 1000000000,
#            'name': 'Chainlink',
#            'num_market_pairs': 633,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#            'quote': {'USD': {'fully_diluted_market_cap': 13407092848.34,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 6261240391.483656,
#                              'market_cap_dominance': 0.3389,
#                              'percent_change_1h': -0.46101325,
#                              'percent_change_24h': -2.93152528,
#                              'percent_change_30d': -17.3649379,
#                              'percent_change_60d': -3.99610643,
#                              'percent_change_7d': -3.92181408,
#                              'percent_change_90d': -13.11382938,
#                              'price': 13.407092848340044,
#                              'volume_24h': 331182136.7986454,
#                              'volume_change_24h': -37.0272}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'chainlink',
#            'symbol': 'LINK',
#            'tags': ['platform',
#                     'defi',
#                     'oracles',
#                     'smart-contracts',
#                     'substrate',
#                     'polkadot',
#                     'polkadot-ecosystem',
#                     'avalanche-ecosystem',
#                     'solana-ecosystem',
#                     'framework-ventures-portfolio',
#                     'polygon-ecosystem',
#                     'fantom-ecosystem',
#                     'cardano-ecosystem',
#                     'web3',
#                     'near-protocol-ecosystem',
#                     'arbitrum-ecosytem',
#                     'cardano',
#                     'injective-ecosystem',
#                     'bnb-chain'],
#            'total_supply': 1000000000},
#           {'circulating_supply': 690502010.1443524,
#            'cmc_rank': 25,
#            'date_added': '2020-09-17T00:00:00.000Z',
#            'id': 7083,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 1000000000,
#            'name': 'Uniswap',
#            'num_market_pairs': 355,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#            'quote': {'USD': {'fully_diluted_market_cap': 9004701226.01,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 6217764297.312358,
#                              'market_cap_dominance': 0.3366,
#                              'percent_change_1h': -0.25098718,
#                              'percent_change_24h': -0.31801461,
#                              'percent_change_30d': -15.01355998,
#                              'percent_change_60d': 2.55952003,
#                              'percent_change_7d': -5.56800822,
#                              'percent_change_90d': -18.1130751,
#                              'price': 9.004701226014545,
#                              'volume_24h': 211833187.0139163,
#                              'volume_change_24h': -26.9099}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'uniswap',
#            'symbol': 'UNI',
#            'tags': ['decentralized-exchange',
#                     'defi',
#                     'dao',
#                     'yield-farming',
#                     'amm',
#                     'coinbase-ventures-portfolio',
#                     'three-arrows-capital-portfolio',
#                     'governance',
#                     'blockchain-capital-portfolio',
#                     'defiance-capital-portfolio',
#                     'alameda-research-portfolio',
#                     'a16z-portfolio',
#                     'pantera-capital-portfolio',
#                     'parafi-capital',
#                     'paradigm-portfolio',
#                     'arbitrum-ecosytem',
# ...
#                              'percent_change_1h': 0.35899626,
#                              'percent_change_24h': 8.40702521,
#                              'percent_change_30d': 210.84259579,
#                              'percent_change_60d': 257.86968785,
#                              'percent_change_7d': 16.01231198,
#                              'percent_change_90d': 239.93791103,
#                              'price': 3.109212161544865e-08,
#                              'volume_24h': 1303157.27148309,
#                              'volume_change_24h': 40.2034}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'vita-inu',
#            'symbol': 'VINU',
#            'tags': [],
#            'total_supply': 969729503028290.2},
#           {'circulating_supply': 24810137,
#            'cmc_rank': 992,
#            'date_added': '2021-04-12T00:00:00.000Z',
#            'id': 9200,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 100000000,
#            'name': 'Revomon',
#            'num_market_pairs': 11,
#            'platform': {'id': 1839,
#                         'name': 'BNB '
#                                 'Smart '
#                                 'Chain '
#                                 '(BEP20)',
#                         'slug': 'bnb',
#                         'symbol': 'BNB',
#                         'token_address': '0x155040625D7ae3e9caDA9a73E3E44f76D3Ed1409'},
#            'quote': {'USD': {'fully_diluted_market_cap': 34449207.1,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8546895.478008168,
#                              'market_cap_dominance': 0,
#                              'percent_change_1h': -0.22853777,
#                              'percent_change_24h': 0.86680489,
#                              'percent_change_30d': 3.97089341,
#                              'percent_change_60d': 7.99881575,
#                              'percent_change_7d': 3.06302497,
#                              'percent_change_90d': -19.10371306,
#                              'price': 0.3444920710437096,
#                              'volume_24h': 887940.25826809,
#                              'volume_change_24h': 13.9938}},
#            'self_reported_circulating_supply': 24158360,
#            'self_reported_market_cap': 8322363.469419512,
#            'slug': 'revomon',
#            'symbol': 'REVO',
#            'tags': ['vr-ar',
#                     'collectibles-nfts',
#                     'gaming',
#                     'metaverse',
#                     'play-to-earn',
#                     'bnb-chain'],
#            'total_supply': 100000000},
#           {'circulating_supply': 23949.934603,
#            'cmc_rank': 993,
#            'date_added': '2020-12-16T00:00:00.000Z',
#            'id': 8025,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 0,
#            'name': 'Mirrored '
#                    'Invesco '
#                    'QQQ '
#                    'Trust',
#            'num_market_pairs': 4,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x13B02c8dE71680e71F0820c996E4bE43c2F57d15'},
#            'quote': {'USD': {'fully_diluted_market_cap': 8546401.17,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8546401.166476559,
#                              'market_cap_dominance': 0,
#                              'percent_change_1h': -0.12310553,
#                              'percent_change_24h': -0.22197819,
#                              'percent_change_30d': -6.65343815,
#                              'percent_change_60d': 2.29117303,
#                              'percent_change_7d': -6.5198561,
#                              'percent_change_90d': 1.03546313,
#                              'price': 356.8444468907245,
#                              'volume_24h': 19784.20525185,
#                              'volume_change_24h': -35.628}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'mirrored-invesco-qqq-trust',
#            'symbol': 'mQQQ',
#            'tags': [],
#            'total_supply': 23949.934603},
#           {'circulating_supply': 331228683.9089087,
#            'cmc_rank': 994,
#            'date_added': '2018-04-20T00:00:00.000Z',
#            'id': 2658,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Smart '
#                    'MFG',
#            'num_market_pairs': 10,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x6710c63432a2de02954fc0f851db07146a6c0312'},
#            'quote': {'USD': {'fully_diluted_market_cap': 22304655.59,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8506953.768434096,
#                              'market_cap_dominance': 0.0005,
#                              'percent_change_1h': 0.10251694,
#                              'percent_change_24h': 1.5819893,
#                              'percent_change_30d': -16.57119648,
#                              'percent_change_60d': -60.81060469,
#                              'percent_change_7d': -1.58529895,
#                              'percent_change_90d': -70.26585596,
#                              'price': 0.02568302258138246,
#                              'volume_24h': 69058.26105475,
#                              'volume_change_24h': -4.8609}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'smart-mfg',
#            'symbol': 'MFG',
#            'tags': ['manufacturing',
#                     'logistics',
#                     'enterprise-solutions',
#                     'collectibles-nfts',
#                     'data-provenance',
#                     'defi',
#                     'iot',
#                     'payments',
#                     'smart-contracts'],
#            'total_supply': 868459135.7414333},
#           {'circulating_supply': 45558153243,
#            'cmc_rank': 995,
#            'date_added': '2020-11-09T00:00:00.000Z',
#            'id': 7622,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 1000000000000,
#            'name': 'UBIX.Network',
#            'num_market_pairs': 9,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 186556614.49,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8499174.831576876,
#                              'market_cap_dominance': 0,
#                              'percent_change_1h': 0.30010638,
#                              'percent_change_24h': -4.58684631,
#                              'percent_change_30d': -10.66134542,
#                              'percent_change_60d': -14.08827718,
#                              'percent_change_7d': -2.64518651,
#                              'percent_change_90d': -25.07147795,
#                              'price': 0.0001865566144932087,
#                              'volume_24h': 1051078.3859809,
#                              'volume_change_24h': -42.0934}},
#            'self_reported_circulating_supply': 45558153243,
#            'self_reported_market_cap': 8499174.831576876,
#            'slug': 'ubix-network',
#            'symbol': 'UBX',
#            'tags': ['dag',
#                     'ethereum-ecosystem'],
#            'total_supply': 1000000000},
#           {'circulating_supply': 200000000,
#            'cmc_rank': 996,
#            'date_added': '2018-03-10T00:00:00.000Z',
#            'id': 2576,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Tokenomy',
#            'num_market_pairs': 5,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xdd16ec0f66e54d453e6756713e533355989040e4'},
#            'quote': {'USD': {'fully_diluted_market_cap': 8486523.84,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8486523.84298,
#                              'market_cap_dominance': 0.0005,
#                              'percent_change_1h': -0.16260163,
#                              'percent_change_24h': -2.34641924,
#                              'percent_change_30d': 5.24059069,
#                              'percent_change_60d': -6.58235277,
#                              'percent_change_7d': -8.46553229,
#                              'percent_change_90d': -1.76917202,
#                              'price': 0.0424326192149,
#                              'volume_24h': 19719.3189292,
#                              'volume_change_24h': -34.7595}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'tokenomy',
#            'symbol': 'TEN',
#            'tags': ['marketplace'],
#            'total_supply': 200000000},
#           {'circulating_supply': 919556.05608359,
#            'cmc_rank': 997,
#            'date_added': '2021-01-02T00:00:00.000Z',
#            'id': 8161,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Shopping',
#            'num_market_pairs': 19,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x9b02dd390a603add5c07f9fd9175b7dabe8d63b7'},
#            'quote': {'USD': {'fully_diluted_market_cap': 9227135.96,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8484868.748870317,
#                              'market_cap_dominance': 0,
#                              'percent_change_1h': -0.17928195,
#                              'percent_change_24h': -1.30800429,
#                              'percent_change_30d': 13.56783255,
#                              'percent_change_60d': 3.97873592,
#                              'percent_change_7d': 4.62990639,
#                              'percent_change_90d': -17.35069519,
#                              'price': 9.227135956243455,
#                              'volume_24h': 276497.0791558,
#                              'volume_change_24h': -37.0827}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'shopping',
#            'symbol': 'SPI',
#            'tags': ['e-commerce',
#                     'bnb-chain'],
#            'total_supply': 1000000},
#           {'circulating_supply': 5491860.1987553,
#            'cmc_rank': 998,
#            'date_added': '2018-09-24T00:00:00.000Z',
#            'id': 3336,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': 5491860,
#            'name': 'IQeon',
#            'num_market_pairs': 11,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x0db8d8b76bc361bacbb72e2c491e06085a97ab31'},
#            'quote': {'USD': {'fully_diluted_market_cap': 8440723.13,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8440723.431398645,
#                              'market_cap_dominance': 0,
#                              'percent_change_1h': -0.39628266,
#                              'percent_change_24h': 0.47277584,
#                              'percent_change_30d': -42.32727531,
#                              'percent_change_60d': -49.50668891,
#                              'percent_change_7d': -3.77721216,
#                              'percent_change_90d': -37.45963223,
#                              'price': 1.536951620383871,
#                              'volume_24h': 152782.89159119,
#                              'volume_change_24h': -3.4785}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'iqeon',
#            'symbol': 'IQN',
#            'tags': ['gaming',
#                     'entertainment'],
#            'total_supply': 5491860.1987553},
#           {'circulating_supply': 158400100,
#            'cmc_rank': 999,
#            'date_added': '2019-05-24T00:00:00.000Z',
#            'id': 3965,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'TouchCon',
#            'num_market_pairs': 4,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x549905519f9e06d55d7dfcd4d54817780f6b93e8'},
#            'quote': {'USD': {'fully_diluted_market_cap': 52741784.29,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8438690.81407331,
#                              'market_cap_dominance': 0,
#                              'percent_change_1h': -0.0570114,
#                              'percent_change_24h': -1.7041845,
#                              'percent_change_30d': 164.3107415,
#                              'percent_change_60d': 481.46054944,
#                              'percent_change_7d': -17.61499477,
#                              'percent_change_90d': 818.98748279,
#                              'price': 0.05327452958724969,
#                              'volume_24h': 14.31001695,
#                              'volume_change_24h': 1957.0644}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'touchcon',
#            'symbol': 'TOC',
#            'tags': [],
#            'total_supply': 990000000},
#           {'circulating_supply': 18895370.24235427,
#            'cmc_rank': 1000,
#            'date_added': '2017-09-12T00:00:00.000Z',
#            'id': 1955,
#            'last_updated': '2022-04-23T19:41:00.000Z',
#            'max_supply': None,
#            'name': 'Neblio',
#            'num_market_pairs': 6,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 8529817.65,
#                              'last_updated': '2022-04-23T19:41:00.000Z',
#                              'market_cap': 8423336.514293365,
#                              'market_cap_dominance': 0.0005,
#                              'percent_change_1h': -1.43638778,
#                              'percent_change_24h': -5.54903635,
#                              'percent_change_30d': 4.08577441,
#                              'percent_change_60d': -13.58645806,
#                              'percent_change_7d': -3.65888387,
#                              'percent_change_90d': -15.72283048,
#                              'price': 0.44578838129418197,
#                              'volume_24h': 302585.03729613,
#                              'volume_change_24h': 52.5596}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'neblio',
#            'symbol': 'NEBL',
#            'tags': ['platform',
#                     'enterprise-solutions'],
#            'total_supply': 19134230.51983088}],
#  'status': {'credit_count': 5,
#             'elapsed': 156,
#             'error_code': 0,
#             'error_message': None,
#             'notice': None,
#             'timestamp': '2022-04-23T19:42:22.001Z',
#             'total_count': 10018}}

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)
db = client.cryptoCurrency_db
collection = db.items

# %%
for item in data_retrieved:

    collection.insert_one(item)

# %%
docs = pd.DataFrame(columns=[])
items = db.items.find()
for num, doc in enumerate(items):
    doc["_id"] = str(doc["_id"])
    doc_id = doc["_id"]
    series_obj = pd.Series(doc, name=doc_id)
    docs = docs.append(series_obj)

# %%
data_df = pd.DataFrame(docs["data"][0])
data_df["date_added"] = pd.to_datetime(data_df["date_added"])
data_df["year"] = pd.DatetimeIndex(data_df["date_added"]).year
data_df.head(2)
# Out:
#      id      name symbol      slug  num_market_pairs  \
# 0     1   Bitcoin    BTC   bitcoin              9357
# 1  1027  Ethereum    ETH  ethereum              5661
#
#                  date_added  \
# 0 2013-04-28 00:00:00+00:00
# 1 2015-08-07 00:00:00+00:00
#
#                                                 tags  max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...  21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...         NaN
#
#    circulating_supply  total_supply platform  cmc_rank  \
# 0        1.902007e+07  1.902007e+07     None         1
# 1        1.204986e+08  1.204986e+08     None         2
#
#    self_reported_circulating_supply  self_reported_market_cap  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
#
#                last_updated  \
# 0  2022-04-23T19:42:00.000Z
# 1  2022-04-23T19:41:00.000Z
#
#                                                quote  year
# 0  {'USD': {'price': 39732.432568576856, 'volume_...  2013
# 1  {'USD': {'price': 2951.497484058154, 'volume_2...  2015

# %%
df = pd.DataFrame.from_dict(data_df)
df.head(2)
df["date_added"] = pd.to_datetime(df["date_added"])
df["year"] = pd.DatetimeIndex(df["date_added"]).year

# %%
df = df["quote"].apply(pd.Series)
df.head(2)
# Out:
#                                                  USD
# 0  {'price': 39732.432568576856, 'volume_24h': 16...
# 1  {'price': 2951.497484058154, 'volume_24h': 971...

# %%
df = df.USD.apply(pd.Series)
df.head(2)
# Out:
#           price    volume_24h  volume_change_24h  percent_change_1h  \
# 0  39732.432569  1.665930e+10           -47.3935          -0.034540
# 1   2951.497484  9.715132e+09           -49.7670          -0.057011
#
#    percent_change_24h  percent_change_7d  percent_change_30d  \
# 0            0.003928          -1.248341           -9.733043
# 1           -0.887322          -2.507274           -5.258144
#
#    percent_change_60d  percent_change_90d    market_cap  market_cap_dominance  \
# 0            4.534797           13.781847  7.557136e+11               40.8958
# 1           12.748583           22.701376  3.556514e+11               19.2455
#
#    fully_diluted_market_cap              last_updated
# 0              8.343811e+11  2022-04-23T19:42:00.000Z
# 1              3.556514e+11  2022-04-23T19:41:00.000Z

# %%
final_df = pd.concat([data_df, df], axis=1)
final_df = final_df.drop(columns="quote")
final_df
# Out:
#        id      name symbol      slug  num_market_pairs  \
# 0       1   Bitcoin    BTC   bitcoin              9357
# 1    1027  Ethereum    ETH  ethereum              5661
# 2     825    Tether   USDT    tether             32249
# 3    1839       BNB    BNB       bnb               813
# 4    3408  USD Coin   USDC  usd-coin              3801
# ..    ...       ...    ...       ...               ...
# 995  2576  Tokenomy    TEN  tokenomy                 5
# 996  8161  Shopping    SPI  shopping                19
# 997  3336     IQeon    IQN     iqeon                11
# 998  3965  TouchCon    TOC  touchcon                 4
# 999  1955    Neblio   NEBL    neblio                 6
#
#                    date_added  \
# 0   2013-04-28 00:00:00+00:00
# 1   2015-08-07 00:00:00+00:00
# 2   2015-02-25 00:00:00+00:00
# 3   2017-07-25 00:00:00+00:00
# 4   2018-10-08 00:00:00+00:00
# ..                        ...
# 995 2018-03-10 00:00:00+00:00
# 996 2021-01-02 00:00:00+00:00
# 997 2018-09-24 00:00:00+00:00
# 998 2019-05-24 00:00:00+00:00
# 999 2017-09-12 00:00:00+00:00
#
#                                                   tags   max_supply  \
# 0    [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1    [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2    [payments, stablecoin, asset-backed-stablecoin...          NaN
# 3    [marketplace, centralized-exchange, payments, ...  165116760.0
# 4    [medium-of-exchange, stablecoin, asset-backed-...          NaN
# ..                                                 ...          ...
# 995                                      [marketplace]          NaN
# 996                            [e-commerce, bnb-chain]          NaN
# 997                            [gaming, entertainment]    5491860.0
# 998                                                 []          NaN
# 999                   [platform, enterprise-solutions]          NaN
#
#      circulating_supply  total_supply  ... percent_change_1h  \
# 0          1.902007e+07  1.902007e+07  ...         -0.034540
# 1          1.204986e+08  1.204986e+08  ...         -0.057011
# 2          8.311420e+10  8.571395e+10  ...          0.002965
# 3          1.632770e+08  1.632770e+08  ...          0.016126
# 4          4.989235e+10  4.989235e+10  ...          0.045592
# ..                  ...           ...  ...               ...
# 995        2.000000e+08  2.000000e+08  ...         -0.162602
# 996        9.195561e+05  1.000000e+06  ...         -0.179282
# 997        5.491860e+06  5.491860e+06  ...         -0.396283
# 998        1.584001e+08  9.900000e+08  ...         -0.057011
# 999        1.889537e+07  1.913423e+07  ...         -1.436388
#
#      percent_change_24h  percent_change_7d  percent_change_30d  \
# 0              0.003928          -1.248341           -9.733043
# 1             -0.887322          -2.507274           -5.258144
# 2              0.004818           0.002284           -0.021181
# 3             -0.776389          -1.931158           -2.120099
# 4             -0.006661           0.045157            0.066560
# ..                  ...                ...                 ...
# 995           -2.346419          -8.465532            5.240591
# 996           -1.308004           4.629906           13.567833
# 997            0.472776          -3.777212          -42.327275
# 998           -1.704184         -17.614995          164.310742
# 999           -5.549036          -3.658884            4.085774
#
#     percent_change_60d  percent_change_90d    market_cap  \
# 0             4.534797           13.781847  7.557136e+11
# 1            12.748583           22.701376  3.556514e+11
# 2            -0.043373           -0.016517  8.313830e+10
# 3             9.499423           10.934343  6.633072e+10
# 4            -0.003620            0.100152  4.991087e+10
# ..                 ...                 ...           ...
# 995          -6.582353           -1.769172  8.486524e+06
# 996           3.978736          -17.350695  8.484869e+06
# 997         -49.506689          -37.459632  8.440723e+06
# 998         481.460549          818.987483  8.438691e+06
# 999         -13.586458          -15.722830  8.423337e+06
#
#      market_cap_dominance  fully_diluted_market_cap              last_updated
# 0                 40.8958              8.343811e+11  2022-04-23T19:42:00.000Z
# 1                 19.2455              3.556514e+11  2022-04-23T19:41:00.000Z
# 2                  4.5004              8.573880e+10  2022-04-23T19:41:00.000Z
# 3                  3.5902              6.707813e+10  2022-04-23T19:41:00.000Z
# 4                  2.7006              4.991087e+10  2022-04-23T19:41:00.000Z
# ..                    ...                       ...                       ...
# 995                0.0005              8.486524e+06  2022-04-23T19:41:00.000Z
# 996                0.0000              9.227136e+06  2022-04-23T19:41:00.000Z
# 997                0.0000              8.440723e+06  2022-04-23T19:41:00.000Z
# 998                0.0000              5.274178e+07  2022-04-23T19:41:00.000Z
# 999                0.0005              8.529818e+06  2022-04-23T19:41:00.000Z
#
# [1000 rows x 29 columns]

# %%
collection.insert_many(final_df.to_dict("records"))
# Out:
# /var/folders/4p/rh50sq7s6hv5kgschbryjvt80000gn/T/ipykernel_66710/1793185836.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   collection.insert_many(final_df.to_dict('records'))
